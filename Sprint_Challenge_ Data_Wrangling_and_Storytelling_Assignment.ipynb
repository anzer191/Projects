# %% [markdown]
# Task-1

# %%
import pandas as pd
import numpy as np

# %%
cell_phones_url = 'https://raw.githubusercontent.com/pixeltests/datasets/main/cell_phones.csv'
cell_phones=pd.read_csv('https://raw.githubusercontent.com/pixeltests/datasets/main/cell_phones.csv')
cell_phones.head()
# Out:
#    geo  time  cell_phones_total
# 0  abw  1960                0.0
# 1  abw  1965                0.0
# 2  abw  1970                0.0
# 3  abw  1975                0.0
# 4  abw  1976                0.0

# %%
(cell_phones, pd.DataFrame)
# Out:
# (      geo  time  cell_phones_total
#  0     abw  1960                0.0
#  1     abw  1965                0.0
#  2     abw  1970                0.0
#  3     abw  1975                0.0
#  4     abw  1976                0.0
#  ...   ...   ...                ...
#  9569  zwe  2015         12757410.0
#  9570  zwe  2016         12878926.0
#  9571  zwe  2017         14092104.0
#  9572  zwe  2018         12908992.0
#  9573  zwe  2019         13195902.0
#
#  [9574 rows x 3 columns],
#  pandas.core.frame.DataFrame)

# %% [markdown]
# Task-2

# %%
population_url = 'https://raw.githubusercontent.com/pixeltests/datasets/main/population.csv'
population=pd.read_csv('https://raw.githubusercontent.com/pixeltests/datasets/main/population.csv')
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %% [markdown]
# Task-3

# %%
geo_codes_url = 'https://raw.githubusercontent.com/pixeltests/datasets/main/geo_country_codes.csv'
geo_codes=pd.read_csv('https://raw.githubusercontent.com/pixeltests/datasets/main/geo_country_codes.csv')
geo_codes.head()
# Out:
#     geo g77_and_oecd_countries income_3groups        income_groups  \
# 0  abkh                 others            NaN                  NaN
# 1   abw                 others    high_income          high_income
# 2   afg                    g77     low_income           low_income
# 3   ago                    g77  middle_income  lower_middle_income
# 4   aia                 others            NaN                  NaN
#
#    is--country iso3166_1_alpha2 iso3166_1_alpha3  iso3166_1_numeric iso3166_2  \
# 0         True              NaN              NaN                NaN       NaN
# 1         True               AW              ABW              533.0       NaN
# 2         True               AF              AFG                4.0       NaN
# 3         True               AO              AGO               24.0       NaN
# 4         True               AI              AIA              660.0       NaN
#
#    landlocked  ...  longitude  main_religion_2008      country  \
# ...

# %% [markdown]
# Task-4

# %%
cell_phones_missing=cell_phones.isnull().sum()
cell_phones_missing
# Out:
# geo                  0
# time                 0
# cell_phones_total    0
# dtype: int64

# %%
cell_phones_missing=cell_phones.isnull().sum().sum()
cell_phones_missing
# Out:
# 0

# %%
population_missing=population.isnull().sum()
population_missing
# Out:
# geo                 0
# time                0
# population_total    0
# dtype: int64

# %%
population_missing=population.isnull().sum().sum()
population_missing
# Out:
# 0

# %%
geo_codes_missing=geo_codes.isnull().sum()
geo_codes_missing
# Out:
# geo                         0
# g77_and_oecd_countries     14
# income_3groups             55
# income_groups              55
# is--country                 0
# iso3166_1_alpha2           27
# iso3166_1_alpha3           26
# iso3166_1_numeric          26
# iso3166_2                 272
# landlocked                 18
# latitude                   32
# longitude                  32
# main_religion_2008         57
# country                     0
# un_sdg_ldc                 24
# un_sdg_region              25
# un_state                    0
# unicef_region              78
# unicode_region_subtag      25
# world_4region               2
# world_6region              13
# dtype: int64

# %%
geo_codes_missing=geo_codes.isnull().sum().sum()
geo_codes_missing
# Out:
# 781

# %% [markdown]
# Task-5

# %%
cell_phones_population=pd.merge(cell_phones,population, on=['geo','time'], how='inner')
cell_phones_population
# Out:
#       geo  time  cell_phones_total  population_total
# 0     afg  1960                0.0           8996967
# 1     afg  1965                0.0           9956318
# 2     afg  1970                0.0          11173654
# 3     afg  1975                0.0          12689164
# 4     afg  1976                0.0          12943093
# ...   ...   ...                ...               ...
# 8925  zwe  2015         12757410.0          13814642
# 8926  zwe  2016         12878926.0          14030338
# 8927  zwe  2017         14092104.0          14236599
# 8928  zwe  2018         12908992.0          14438812
# 8929  zwe  2019         13195902.0          14645473
#
# [8930 rows x 4 columns]

# %% [markdown]
# Task-6

# %%
geo_cell_phone_population=pd.merge(cell_phones_population,geo_codes,on='geo',how='inner')
geo_cell_phone_population
# Out:
#       geo  time  cell_phones_total  population_total g77_and_oecd_countries  \
# 0     afg  1960                0.0           8996967                    g77
# 1     afg  1965                0.0           9956318                    g77
# 2     afg  1970                0.0          11173654                    g77
# 3     afg  1975                0.0          12689164                    g77
# 4     afg  1976                0.0          12943093                    g77
# ...   ...   ...                ...               ...                    ...
# 8925  zwe  2015         12757410.0          13814642                    g77
# 8926  zwe  2016         12878926.0          14030338                    g77
# 8927  zwe  2017         14092104.0          14236599                    g77
# 8928  zwe  2018         12908992.0          14438812                    g77
# 8929  zwe  2019         13195902.0          14645473                    g77
#
# ...

# %%
geo_cell_phone_population=pd.merge(cell_phones_population,geo_codes,on='geo',how='left')
geo_cell_phone_population
# Out:
#       geo  time  cell_phones_total  population_total g77_and_oecd_countries  \
# 0     afg  1960                0.0           8996967                    g77
# 1     afg  1965                0.0           9956318                    g77
# 2     afg  1970                0.0          11173654                    g77
# 3     afg  1975                0.0          12689164                    g77
# 4     afg  1976                0.0          12943093                    g77
# ...   ...   ...                ...               ...                    ...
# 8925  zwe  2015         12757410.0          13814642                    g77
# 8926  zwe  2016         12878926.0          14030338                    g77
# 8927  zwe  2017         14092104.0          14236599                    g77
# 8928  zwe  2018         12908992.0          14438812                    g77
# 8929  zwe  2019         13195902.0          14645473                    g77
#
# ...

# %% [markdown]
# Task-7

# %%
geo_cell_phone_population['phones_per_person']=geo_cell_phone_population['cell_phones_total']/geo_cell_phone_population['population_total']

# %%
geo_cell_phone_population.head()
# Out:
#    geo  time  cell_phones_total  population_total g77_and_oecd_countries  \
# 0  afg  1960                0.0           8996967                    g77
# 1  afg  1965                0.0           9956318                    g77
# 2  afg  1970                0.0          11173654                    g77
# 3  afg  1975                0.0          12689164                    g77
# 4  afg  1976                0.0          12943093                    g77
#
#   income_3groups income_groups  is--country iso3166_1_alpha2 iso3166_1_alpha3  \
# 0     low_income    low_income         True               AF              AFG
# 1     low_income    low_income         True               AF              AFG
# 2     low_income    low_income         True               AF              AFG
# 3     low_income    low_income         True               AF              AFG
# 4     low_income    low_income         True               AF              AFG
#
# ...

# %%
geo_cell_phone_population.tail()
# Out:
#       geo  time  cell_phones_total  population_total g77_and_oecd_countries  \
# 8925  zwe  2015         12757410.0          13814642                    g77
# 8926  zwe  2016         12878926.0          14030338                    g77
# 8927  zwe  2017         14092104.0          14236599                    g77
# 8928  zwe  2018         12908992.0          14438812                    g77
# 8929  zwe  2019         13195902.0          14645473                    g77
#
#      income_3groups        income_groups  is--country iso3166_1_alpha2  \
# 8925  middle_income  lower_middle_income         True               ZW
# 8926  middle_income  lower_middle_income         True               ZW
# 8927  middle_income  lower_middle_income         True               ZW
# 8928  middle_income  lower_middle_income         True               ZW
# 8929  middle_income  lower_middle_income         True               ZW
#
#      iso3166_1_alpha3  ...  main_religion_2008   country  \
# ...

# %% [markdown]
# Task-8

# %%
US_2017=geo_cell_phone_population[geo_cell_phone_population['country']=='United States']
US_2017
# Out:
#       geo  time  cell_phones_total  population_total g77_and_oecd_countries  \
# 8413  usa  1960                0.0         186720570                   oecd
# 8414  usa  1965                0.0         199733679                   oecd
# 8415  usa  1970                0.0         209513340                   oecd
# 8416  usa  1975                0.0         219081250                   oecd
# 8417  usa  1976                0.0         221086427                   oecd
# 8418  usa  1977                0.0         223135659                   oecd
# 8419  usa  1978                0.0         225223307                   oecd
# 8420  usa  1979                0.0         227339321                   oecd
# 8421  usa  1980                0.0         229476360                   oecd
# 8422  usa  1984            91600.0         238256849                   oecd
# 8423  usa  1985           340213.0         240499822                   oecd
# ...

# %%
US_2017=US_2017a['time']='2017'
print(US_2017)
# Out:
# 2017

# %% [markdown]
# Task-9

# %%
geo_cell_phone_population.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'phone_per_person'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
mean_phones=geo_cell_phone_population['phones_per_person'].mean()
mean_phones
# Out:
# 0.31136482560364814

# %%
geo_cell_phone_population.describe().mean()

# %%
geo_cell_phone_population['phone_per_person']=geo_cell_phone_population['population_total']/geo_cell_phone_population['cell_phones_total']

# %% [markdown]
# Task-10

# %%
geo_cell_phone_population.describe(exclude='number')

# %%
 unique_country=geo_cell_phone_population['country'].nunique()
 unique_country

# %% [markdown]
# Task-11

# %%
df2017=geo_cell_phone_population[geo_cell_phone_population['time']==2017]
df2017

# %% [markdown]
# Task-12

# %%
df2017_top=df2017.sort_values('phones_per_person',ascending=False)
df2017_top.head()

# %%
df2017_top.tail()

# %% [markdown]
# Task-13

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.display import display, Image
png = 'https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png'
example = Image(png, width=500)
display(example)

# %% [markdown]
# ANSWER:- THERE ARE TOO MANY VARIABLES WHICH CANNOT BE ALLOTED IN A PIE CHART  AND THE SUM DOESN'T ADD TO 100%

# %% [markdown]
# Task-14

# %%
Titanic = pd.read_csv('https://raw.githubusercontent.com/pixeltests/datasets/main/titanic.csv')

Titanic.head()

# %%
fig,ax=plt.subplots()
ax.hist('Parents/Children_Aboard')
ax.set_xlabel('Parents/Children_Aboard')
ax.set_ylabel('Frequency')
ax.set_title('Family members of a person abaord')
plt.show()

# %%
Titanic['Parents/Children_Aboard'].plot.bar(x='survived')

# %%
Titanic['Parents/Children_Aboard'].plot.hist(x='survived')

# %% [markdown]
# There are lots of parents with no lids or 1 kid
# Right Skewed
