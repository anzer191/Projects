# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Task 1

# %%
data_url1 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/product_names_sm.csv'
product_names=pd.read_csv(data_url1)
product_names
# Out:
#        product_id                                    product_name  aisle_id  \
# 0           45676  Oil Free Acne Stress Control Power Clear Scrub        73
# 1           35408                      Soymilk Vanilla Value Size        91
# 2           37442                                       Vegan Egg        86
# 3           41599                 Organic Echinacea Herb Capsules        47
# 4           21994                      Premium Saline Nasal Spray        11
# ...           ...                                             ...       ...
# 24995       49183                           Sf Protein Thai Style        38
# 24996        7122              Sleek Super Plus Unscented Tampons       126
# 24997       44763                                English Cucumber        83
# 24998        3960               Quietude Quick Dissolving Tablets         6
# 24999       40535                       Brewed Green Tea Iced Tea        98
#
#        department_id
# 0                 11
# ...

# %%
product_names.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0       45676  Oil Free Acne Stress Control Power Clear Scrub        73
# 1       35408                      Soymilk Vanilla Value Size        91
# 2       37442                                       Vegan Egg        86
# 3       41599                 Organic Echinacea Herb Capsules        47
# 4       21994                      Premium Saline Nasal Spray        11
#
#    department_id
# 0             11
# 1             16
# 2             16
# 3             11
# 4             11

# %%
product_names.tail()
# Out:
#        product_id                        product_name  aisle_id  department_id
# 24995       49183               Sf Protein Thai Style        38              1
# 24996        7122  Sleek Super Plus Unscented Tampons       126             11
# 24997       44763                    English Cucumber        83              4
# 24998        3960   Quietude Quick Dissolving Tablets         6              2
# 24999       40535           Brewed Green Tea Iced Tea        98              7

# %%
(product_names, pd.DataFrame)
# Out:
# (       product_id                                    product_name  aisle_id  \
#  0           45676  Oil Free Acne Stress Control Power Clear Scrub        73
#  1           35408                      Soymilk Vanilla Value Size        91
#  2           37442                                       Vegan Egg        86
#  3           41599                 Organic Echinacea Herb Capsules        47
#  4           21994                      Premium Saline Nasal Spray        11
#  ...           ...                                             ...       ...
#  24995       49183                           Sf Protein Thai Style        38
#  24996        7122              Sleek Super Plus Unscented Tampons       126
#  24997       44763                                English Cucumber        83
#  24998        3960               Quietude Quick Dissolving Tablets         6
#  24999       40535                       Brewed Green Tea Iced Tea        98
#
#         department_id
# ...

# %% [markdown]
# Task 2

# %%
data_url2 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/order_products_prior_sm.csv'
data_url3 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/order_products_train_sm.csv'
order_products_prior=pd.read_csv(data_url2)
order_products_train=pd.read_csv(data_url3)

# %%
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   1696715       34969                 11          0
# 1   2077308       16641                 16          0
# 2    303457       46881                  6          0
# 3    514151       31766                  9          0
# 4   2099209        7908                 10          1

# %%
order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   3178234       22620                  2          0
# 1   2319083       27156                 14          0
# 2   1951854        5818                  9          1
# 3   1615787       40198                 13          0
# 4   1666094       14491                 13          0

# %%
order_products=pd.concat([order_products_prior,order_products_train])

# %%
order_products
# Out:
#        order_id  product_id  add_to_cart_order  reordered
# 0       1696715       34969                 11          0
# 1       2077308       16641                 16          0
# 2        303457       46881                  6          0
# 3        514151       31766                  9          0
# 4       2099209        7908                 10          1
# ...         ...         ...                ...        ...
# 24995   1474983       21903                 21          0
# 24996    891325       26209                  5          1
# 24997    151280       13176                  6          1
# 24998   3250616       47719                  4          0
# 24999   2733689       17435                 19          0
#
# [50000 rows x 4 columns]

# %% [markdown]
# Task 3

# %%
top_five_products=["Bag of Organic Bananas", "Organic Baby Spinach", "Organic Avocado", "Large Lemon", "Limes"]
top_five_products
# Out:
# ['Bag of Organic Bananas',
#  'Organic Baby Spinach',
#  'Organic Avocado',
#  'Large Lemon',
#  'Limes']

# %%
(top_five_products, list)
# Out:
# (['Bag of Organic Bananas',
#   'Organic Baby Spinach',
#   'Organic Avocado',
#   'Large Lemon',
#   'Limes'],
#  list)

# %% [markdown]
# Task 4

# %%
five = pd.DataFrame(top_five_products, columns =['product_name'])
top_products=pd.merge(product_names,five,on='product_name',how='inner')
top_products
# Out:
#    product_id            product_name  aisle_id  department_id
# 0       47766         Organic Avocado        24              4
# 1       47626             Large Lemon        24              4
# 2       13176  Bag of Organic Bananas        24              4
# 3       26209                   Limes        24              4
# 4       21903    Organic Baby Spinach       123              4

# %%
top_products=pd.merge(five,product_names,on='product_name',how='left')
top_products
# Out:
#              product_name  product_id  aisle_id  department_id
# 0  Bag of Organic Bananas       13176        24              4
# 1    Organic Baby Spinach       21903       123              4
# 2         Organic Avocado       47766        24              4
# 3             Large Lemon       47626        24              4
# 4                   Limes       26209        24              4

# %% [markdown]
# Task 5

# %%
final=pd.merge(order_products,top_products,on='product_id',how='inner')
final.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0    2469765       26209                 11          0        Limes        24
# 1    2322104       26209                  6          1        Limes        24
# 2    1297655       26209                 15          1        Limes        24
# 3    1397335       26209                  8          1        Limes        24
# 4     651387       26209                  2          1        Limes        24
# 5    1338110       26209                  5          1        Limes        24
# 6    2587073       26209                  2          1        Limes        24
# 7      25158       26209                  9          1        Limes        24
# 8    2652386       26209                 11          1        Limes        24
# 9     440430       26209                  5          1        Limes        24
# 10   1080877       26209                  9          1        Limes        24
# ...

# %%
final.tail(20)
# Out:
#       order_id  product_id  add_to_cart_order  reordered     product_name  \
# 1650    340833       47766                 22          0  Organic Avocado
# 1651    797678       47766                  3          1  Organic Avocado
# 1652   2793915       47766                  3          1  Organic Avocado
# 1653   1874426       47766                  8          0  Organic Avocado
# 1654   1389075       47766                  3          0  Organic Avocado
# 1655   1592739       47766                  5          1  Organic Avocado
# 1656    445861       47766                  1          1  Organic Avocado
# 1657   2870090       47766                  3          1  Organic Avocado
# 1658   2371442       47766                  5          1  Organic Avocado
# 1659    574697       47766                  8          1  Organic Avocado
# 1660   1198960       47766                 32          1  Organic Avocado
# 1661   3267554       47766                  1          1  Organic Avocado
# ...

# %%
final.shape
# Out:
# (1670, 7)

# %%
(top_products, pd.DataFrame)
# Out:
# (             product_name  product_id  aisle_id  department_id
#  0  Bag of Organic Bananas       13176        24              4
#  1    Organic Baby Spinach       21903       123              4
#  2         Organic Avocado       47766        24              4
#  3             Large Lemon       47626        24              4
#  4                   Limes       26209        24              4,
#  pandas.core.frame.DataFrame)

# %% [markdown]
# Task 6

# %%
final['product_id'].value_counts()
# Out:
# 13176    561
# 21903    360
# 47626    283
# 47766    269
# 26209    197
# Name: product_id, dtype: int64

# %%
final['order_id'].value_counts()
# Out:
# 904955     2
# 2413805    2
# 65030      1
# 2474929    1
# 2119151    1
#           ..
# 2050728    1
# 3318856    1
# 3398691    1
# 708259     1
# 2786926    1
# Name: order_id, Length: 1668, dtype: int64

# %%
top_item=13176

# %%
top_item
# Out:
# 13176

# %%
food_frequency=final.value_counts()
food_frequency
# Out:
# order_id  product_id  add_to_cart_order  reordered  product_name            aisle_id  department_id
# 11286     47766       1                  1          Organic Avocado         24        4                1
# 2090036   47626       1                  1          Large Lemon             24        4                1
# 2269956   26209       2                  1          Limes                   24        4                1
# 2268652   47626       19                 0          Large Lemon             24        4                1
# 2267282   21903       7                  1          Organic Baby Spinach    123       4                1
#                                                                                                       ..
# 1077625   13176       5                  1          Bag of Organic Bananas  24        4                1
# 1075175   21903       4                  1          Organic Baby Spinach    123       4                1
# ...

# %%
food_frequency
# Out:
# order_id  product_id  add_to_cart_order  reordered  product_name            aisle_id  department_id
# 11286     47766       1                  1          Organic Avocado         24        4                1
# 2090036   47626       1                  1          Large Lemon             24        4                1
# 2269956   26209       2                  1          Limes                   24        4                1
# 2268652   47626       19                 0          Large Lemon             24        4                1
# 2267282   21903       7                  1          Organic Baby Spinach    123       4                1
#                                                                                                       ..
# 1077625   13176       5                  1          Bag of Organic Bananas  24        4                1
# 1075175   21903       4                  1          Organic Baby Spinach    123       4                1
# ...

# %%
food_frequency.shape
# Out:
# (1670,)

# %%
food_frequency.head()
# Out:
# order_id  product_id  add_to_cart_order  reordered  product_name          aisle_id  department_id
# 11286     47766       1                  1          Organic Avocado       24        4                1
# 2090036   47626       1                  1          Large Lemon           24        4                1
# 2269956   26209       2                  1          Limes                 24        4                1
# 2268652   47626       19                 0          Large Lemon           24        4                1
# 2267282   21903       7                  1          Organic Baby Spinach  123       4                1
# dtype: int64

# %% [markdown]
# Task 7

# %%
data_url4 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/orders_sm.csv'
orders = pd.read_csv(data_url4)

# %%
orders
# Out:
#        order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0        209450     4647    prior            36          1                 16
# 1       2381956   117152    prior            14          0                 12
# 2       2294641   123531    prior            50          0                 13
# 3       2674353   167358    prior            14          1                 11
# 4       1776425    14814    prior            13          1                 19
# ...         ...      ...      ...           ...        ...                ...
# 24995   1907583    52553    prior             8          0                 14
# 24996   2030640     6573    prior            26          1                  8
# 24997   2833651   134377    prior            56          5                 12
# 24998   3069074   157142    prior            36          6                 12
# 24999   1654856    30884    prior            13          2                 17
#
#        days_since_prior_order
# ...

# %%
final_times=pd.merge(orders,final,on='order_id',how='right')
final_times
# Out:
#       order_id   user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0      2469765       NaN      NaN           NaN        NaN                NaN
# 1      2322104       NaN      NaN           NaN        NaN                NaN
# 2      1297655       NaN      NaN           NaN        NaN                NaN
# 3      1397335       NaN      NaN           NaN        NaN                NaN
# 4       651387       NaN      NaN           NaN        NaN                NaN
# ...        ...       ...      ...           ...        ...                ...
# 1665   2307907       NaN      NaN           NaN        NaN                NaN
# 1666   1647193  113581.0    train           5.0        0.0               19.0
# 1667   2770916       NaN      NaN           NaN        NaN                NaN
# 1668   2668355       NaN      NaN           NaN        NaN                NaN
# 1669   2786926       NaN      NaN           NaN        NaN                NaN
#
# ...

# %%
mean_hours=final_times.groupby('product_id').mean()
mean_hours
# Out:
# <ipython-input-57-f0ec2850a056>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_hours=final_times.groupby('product_id').mean()
#                 order_id        user_id  order_number  order_dow  \
# product_id
# 13176       1.678524e+06   69894.800000     21.000000        3.8
# 21903       1.674265e+06  132348.750000     33.250000        3.0
# 26209       1.661978e+06   39452.333333      4.666667        6.0
# 47626       1.769667e+06   54319.000000      2.000000        0.0
# 47766       1.655642e+06   76639.250000     10.750000        3.5
#
#             order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# product_id
# 13176               13.200000                   13.00           4.875223
# 21903               14.500000                    7.25           7.711111
# ...

# %%
mean_hours.head()
# Out:
#                 order_id        user_id  order_number  order_dow  \
# product_id
# 13176       1.678524e+06   69894.800000     21.000000        3.8
# 21903       1.674265e+06  132348.750000     33.250000        3.0
# 26209       1.661978e+06   39452.333333      4.666667        6.0
# 47626       1.769667e+06   54319.000000      2.000000        0.0
# 47766       1.655642e+06   76639.250000     10.750000        3.5
#
#             order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# product_id
# 13176               13.200000                   13.00           4.875223
# 21903               14.500000                    7.25           7.711111
# 26209               10.333333                   10.00           8.543147
# 47626               16.000000                   30.00           7.844523
# 47766               17.500000                   20.25           5.973978
#
#             reordered  aisle_id  department_id
# product_id
# 13176        0.839572      24.0            4.0
# ...

# %%
mean_hours=final_times.groupby('product_id')['order_hour_of_day'].mean()
mean_hours
# Out:
# product_id
# 13176    13.200000
# 21903    14.500000
# 26209    10.333333
# 47626    16.000000
# 47766    17.500000
# Name: order_hour_of_day, dtype: float64

# %%
mean_hours.shape
# Out:
# (5,)

# %% [markdown]
# Task 8

# %%
time_limes_1=final_times.groupby('product_id')['order_hour_of_day'].mean()
time_limes=10.333

# %%
time_limes_1
# Out:
# product_id
# 13176    13.200000
# 21903    14.500000
# 26209    10.333333
# 47626    16.000000
# 47766    17.500000
# Name: order_hour_of_day, dtype: float64

# %%
time_spinach=14.5
