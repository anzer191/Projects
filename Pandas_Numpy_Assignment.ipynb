# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Task 1 - Load a dataset via its URL

# %%
data_url='https://raw.githubusercontent.com/LambdaSchool/data-science-practice-datasets/main/unit_1/NASCAR/nascard.csv'
df=pd.read_csv(data_url)
df
# Out:
#        serRace  year  yearRace  finish  start  laps  prize  carsRace  \
# 0            1  1975         1       1      1   191  12035        35
# 1            1  1975         1       2      2   191   8135        35
# 2            1  1975         1       3     25   184   6535        35
# 3            1  1975         1       4     27   183   5035        35
# 4            1  1975         1       5     22   178   3835        35
# ...        ...   ...       ...     ...    ...   ...    ...       ...
# 34879      898  2003        36      39     17    89  43150        43
# 34880      898  2003        36      40     26    81  78703        43
# 34881      898  2003        36      41     23    72  60735        43
# 34882      898  2003        36      42     22    57  67612        43
# 34883      898  2003        36      43     37    28  62665        43
#
#          carMake          driver
# 0        Matador    BobbyAllison
# 1        Mercury    DavidPearson
# 2      Chevrolet     CecilGordon
# 3          Dodge      DaveMarcis
# 4           Ford     ElmoLangley
# ...          ...             ...
# 34879  Chevrolet     MikeSkinner
# 34880      Dodge       JeffGreen
# 34881  Chevrolet  MichaelWaltrip
# 34882  Chevrolet    JohnAndretti
# 34883       Ford     MattKenseth
#
# [34884 rows x 10 columns]

# %% [markdown]
# Task 2 - Look at the first and last rows of the DataFrame
#
# Assign the first ten (10) rows of the adult DataFrame to adult_head
# Assign the last ten (10) rows of the adult DataFrame to adult_tail

# %%
df.head()
# Out:
#    serRace  year  yearRace  finish  start  laps  prize  carsRace    carMake  \
# 0        1  1975         1       1      1   191  12035        35    Matador
# 1        1  1975         1       2      2   191   8135        35    Mercury
# 2        1  1975         1       3     25   184   6535        35  Chevrolet
# 3        1  1975         1       4     27   183   5035        35      Dodge
# 4        1  1975         1       5     22   178   3835        35       Ford
#
#          driver
# 0  BobbyAllison
# 1  DavidPearson
# 2   CecilGordon
# 3    DaveMarcis
# 4   ElmoLangley

# %%
df.tail()
# Out:
#        serRace  year  yearRace  finish  start  laps  prize  carsRace  \
# 34879      898  2003        36      39     17    89  43150        43
# 34880      898  2003        36      40     26    81  78703        43
# 34881      898  2003        36      41     23    72  60735        43
# 34882      898  2003        36      42     22    57  67612        43
# 34883      898  2003        36      43     37    28  62665        43
#
#          carMake          driver
# 34879  Chevrolet     MikeSkinner
# 34880      Dodge       JeffGreen
# 34881  Chevrolet  MichaelWaltrip
# 34882  Chevrolet    JohnAndretti
# 34883       Ford     MattKenseth

# %%
df.head(10)
# Out:
#    serRace  year  yearRace  finish  start  laps  prize  carsRace    carMake  \
# 0        1  1975         1       1      1   191  12035        35    Matador
# 1        1  1975         1       2      2   191   8135        35    Mercury
# 2        1  1975         1       3     25   184   6535        35  Chevrolet
# 3        1  1975         1       4     27   183   5035        35      Dodge
# 4        1  1975         1       5     22   178   3835        35       Ford
# 5        1  1975         1       6     35   175   2885        35  Chevrolet
# 6        1  1975         1       7      3   172   3185        35      Dodge
# 7        1  1975         1       8     21   168   2485        35  Chevrolet
# 8        1  1975         1       9     33   167   2335        35      Dodge
# 9        1  1975         1      10     10   166   2185        35  Chevrolet
#
#            driver
# 0    BobbyAllison
# 1    DavidPearson
# 2     CecilGordon
# 3      DaveMarcis
# 4     ElmoLangley
# 5     JamesHylton
# 6    RichardPetty
# 7    GaryMatthews
# 8         EdNegre
# 9  HershelMcGriff

# %%
df.tail(10)
# Out:
#        serRace  year  yearRace  finish  start  laps  prize  carsRace  \
# 34874      898  2003        36      34      3   220  44175        43
# 34875      898  2003        36      35     25   197  43975        43
# 34876      898  2003        36      36      7   147  63760        43
# 34877      898  2003        36      37      4   122  73425        43
# 34878      898  2003        36      38     33   121  43350        43
# 34879      898  2003        36      39     17    89  43150        43
# 34880      898  2003        36      40     26    81  78703        43
# 34881      898  2003        36      41     23    72  60735        43
# 34882      898  2003        36      42     22    57  67612        43
# 34883      898  2003        36      43     37    28  62665        43
#
#          carMake          driver
# 34874  Chevrolet    BrianVickers
# 34875       Ford      GregBiffle
# 34876       Ford       KurtBusch
# 34877      Dodge      RyanNewman
# 34878  Chevrolet    HermieSadler
# 34879  Chevrolet     MikeSkinner
# 34880      Dodge       JeffGreen
# 34881  Chevrolet  MichaelWaltrip
# 34882  Chevrolet    JohnAndretti
# 34883       Ford     MattKenseth

# %% [markdown]
# Task 3 - Variable data types

# %%
df.value_counts()
# Out:
# serRace  year  yearRace  finish  start  laps  prize  carsRace  carMake    driver
# 1        1975  1         1       1      191   12035  35        Matador    BobbyAllison      1
# 626      1995  31        25      3      321   11985  42        Pontiac    BobbyHamilton     1
#                          19      36     324   12775  42        Ford       LakeSpeed         1
#                          20      20     324   23410  42        Ford       BrettBodine       1
#                          21      13     324   17145  42        Ford       RickMast          1
#                                                                                            ..
# 326      1985  23        24      1      288   10285  31        Chevrolet  GeoffreyBodine    1
#                          23      23     310   2865   31        Chevrolet  DaveMarcis        1
#                          22      14     334   6405   31        Pontiac    RichardPetty      1
#                          21      22     389   2895   31        Ford       BuddyArrington    1
# 898      2003  36        43      37     28    62665  43        Ford       MattKenseth       1
# Length: 34884, dtype: int64

# %%
df.describe(include='number')
# Out:
#             serRace          year      yearRace        finish         start  \
# count  34884.000000  34884.000000  34884.000000  34884.000000  34884.000000
# mean     468.597151   1990.027950     16.175811     20.203102     20.205510
# std      259.245275      8.523917      9.133874     11.645944     11.648361
# min        1.000000   1975.000000      1.000000      1.000000      1.000000
# 25%      247.000000   1983.000000      8.000000     10.000000     10.000000
# 50%      478.000000   1991.000000     16.000000     20.000000     20.000000
# 75%      696.000000   1998.000000     24.000000     30.000000     30.000000
# max      898.000000   2003.000000     36.000000     50.000000     58.000000
#
#                laps         prize      carsRace
# count  34884.000000  3.488400e+04  34884.000000
# mean     261.924120  2.704011e+04     39.406146
# std      140.104744  4.455498e+04      4.348333
# min        0.000000  0.000000e+00     22.000000
# 25%      159.000000  3.835000e+03     37.000000
# 50%      253.000000  1.201000e+04     41.000000
# 75%      390.000000  3.649625e+04     43.000000
# max      500.000000  2.277975e+06     50.000000

# %%
df.describe()
# Out:
#             serRace          year      yearRace        finish         start  \
# count  34884.000000  34884.000000  34884.000000  34884.000000  34884.000000
# mean     468.597151   1990.027950     16.175811     20.203102     20.205510
# std      259.245275      8.523917      9.133874     11.645944     11.648361
# min        1.000000   1975.000000      1.000000      1.000000      1.000000
# 25%      247.000000   1983.000000      8.000000     10.000000     10.000000
# 50%      478.000000   1991.000000     16.000000     20.000000     20.000000
# 75%      696.000000   1998.000000     24.000000     30.000000     30.000000
# max      898.000000   2003.000000     36.000000     50.000000     58.000000
#
#                laps         prize      carsRace
# count  34884.000000  3.488400e+04  34884.000000
# mean     261.924120  2.704011e+04     39.406146
# std      140.104744  4.455498e+04      4.348333
# min        0.000000  0.000000e+00     22.000000
# 25%      159.000000  3.835000e+03     37.000000
# 50%      253.000000  1.201000e+04     41.000000
# 75%      390.000000  3.649625e+04     43.000000
# max      500.000000  2.277975e+06     50.000000

# %%
df.describe(exclude='number')
# Out:
#           carMake     driver
# count       34884      34884
# unique         10        683
# top     Chevrolet  RickyRudd
# freq        12663        803

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34884 entries, 0 to 34883
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   serRace   34884 non-null  int64
#  1   year      34884 non-null  int64
#  2   yearRace  34884 non-null  int64
#  3   finish    34884 non-null  int64
#  4   start     34884 non-null  int64
#  5   laps      34884 non-null  int64
#  6   prize     34884 non-null  int64
#  7   carsRace  34884 non-null  int64
#  8   carMake   34884 non-null  object
#  9   driver    34884 non-null  object
# dtypes: int64(8), object(2)
# memory usage: 2.7+ MB

# %%
df.dtypes
# Out:
# serRace      int64
# year         int64
# yearRace     int64
# finish       int64
# start        int64
# laps         int64
# prize        int64
# carsRace     int64
# carMake     object
# driver      object
# dtype: object

# %% [markdown]
# Task 4 - DataFrame dimensions

# %%
df.shape
# Out:
# (34884, 10)

# %%
df.size
# Out:
# 348840

# %% [markdown]
# Task 5 - Missing values

# %%
df.isnull().sum()
# Out:
# serRace     0
# year        0
# yearRace    0
# finish      0
# start       0
# laps        0
# prize       0
# carsRace    0
# carMake     0
# driver      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Tast 6-Viewing DataFrame statistics

# %%
df.mean()
# Out:
# <ipython-input-85-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# serRace       468.597151
# year         1990.027950
# yearRace       16.175811
# finish         20.203102
# start          20.205510
# laps          261.924120
# prize       27040.108474
# carsRace       39.406146
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-86-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# serRace       259.245275
# year            8.523917
# yearRace        9.133874
# finish         11.645944
# start          11.648361
# laps          140.104744
# prize       44554.975963
# carsRace        4.348333
# dtype: float64

# %% [markdown]
# Task 7 - Summary statistics for non-numeric columns

# %%
df.describe(exclude='number')
# Out:
#        ATLANTA MOTOR SPEEDWAY                          24     1.54  197.478
# count                                                  20
# unique                                                 20
# top     BRISTOL MOTOR SPEEDWAY                        ...
# freq                                                    1

# %%
df
# Out:
#        serRace  year  yearRace  finish  start  laps  prize  carsRace  \
# 0            1  1975         1       1      1   191  12035        35
# 1            1  1975         1       2      2   191   8135        35
# 2            1  1975         1       3     25   184   6535        35
# 3            1  1975         1       4     27   183   5035        35
# 4            1  1975         1       5     22   178   3835        35
# ...        ...   ...       ...     ...    ...   ...    ...       ...
# 34879      898  2003        36      39     17    89  43150        43
# 34880      898  2003        36      40     26    81  78703        43
# 34881      898  2003        36      41     23    72  60735        43
# 34882      898  2003        36      42     22    57  67612        43
# 34883      898  2003        36      43     37    28  62665        43
#
#          carMake          driver
# 0        Matador    BobbyAllison
# 1        Mercury    DavidPearson
# 2      Chevrolet     CecilGordon
# 3          Dodge      DaveMarcis
# 4           Ford     ElmoLangley
# ...          ...             ...
# 34879  Chevrolet     MikeSkinner
# 34880      Dodge       JeffGreen
# 34881  Chevrolet  MichaelWaltrip
# 34882  Chevrolet    JohnAndretti
# 34883       Ford     MattKenseth
#
# [34884 rows x 10 columns]

# %% [markdown]
# Task 8 - Finding value counts

# %%
df.value_counts()
# Out:
# serRace  year  yearRace  finish  start  laps  prize  carsRace  carMake    driver
# 1        1975  1         1       1      191   12035  35        Matador    BobbyAllison      1
# 626      1995  31        25      3      321   11985  42        Pontiac    BobbyHamilton     1
#                          19      36     324   12775  42        Ford       LakeSpeed         1
#                          20      20     324   23410  42        Ford       BrettBodine       1
#                          21      13     324   17145  42        Ford       RickMast          1
#                                                                                            ..
# 326      1985  23        24      1      288   10285  31        Chevrolet  GeoffreyBodine    1
#                          23      23     310   2865   31        Chevrolet  DaveMarcis        1
#                          22      14     334   6405   31        Pontiac    RichardPetty      1
#                          21      22     389   2895   31        Ford       BuddyArrington    1
# 898      2003  36        43      37     28    62665  43        Ford       MattKenseth       1
# Length: 34884, dtype: int64

# %%
df.value_counts()
# Out:
# serRace  year  yearRace  finish  start  laps  prize  carsRace  carMake    driver
# 1        1975  1         1       1      191   12035  35        Matador    BobbyAllison      1
# 626      1995  31        25      3      321   11985  42        Pontiac    BobbyHamilton     1
#                          19      36     324   12775  42        Ford       LakeSpeed         1
#                          20      20     324   23410  42        Ford       BrettBodine       1
#                          21      13     324   17145  42        Ford       RickMast          1
#                                                                                            ..
# 326      1985  23        24      1      288   10285  31        Chevrolet  GeoffreyBodine    1
#                          23      23     310   2865   31        Chevrolet  DaveMarcis        1
#                          22      14     334   6405   31        Pontiac    RichardPetty      1
#                          21      22     389   2895   31        Ford       BuddyArrington    1
# 898      2003  36        43      37     28    62665  43        Ford       MattKenseth       1
# Length: 34884, dtype: int64

# %% [markdown]
# Task 9 - Create a Series

# %%
(df, pd.Series)
# Out:
# (       serRace  year  yearRace  finish  start  laps  prize  carsRace  \
#  0            1  1975         1       1      1   191  12035        35
#  1            1  1975         1       2      2   191   8135        35
#  2            1  1975         1       3     25   184   6535        35
#  3            1  1975         1       4     27   183   5035        35
#  4            1  1975         1       5     22   178   3835        35
#  ...        ...   ...       ...     ...    ...   ...    ...       ...
#  34879      898  2003        36      39     17    89  43150        43
#  34880      898  2003        36      40     26    81  78703        43
#  34881      898  2003        36      41     23    72  60735        43
#  34882      898  2003        36      42     22    57  67612        43
#  34883      898  2003        36      43     37    28  62665        43
#
#           carMake          driver
#  0        Matador    BobbyAllison
#  1        Mercury    DavidPearson
#  2      Chevrolet     CecilGordon
#  3          Dodge      DaveMarcis
#  4           Ford     ElmoLangley
#  ...          ...             ...
#  34879  Chevrolet     MikeSkinner
#  34880      Dodge       JeffGreen
#  34881  Chevrolet  MichaelWaltrip
#  34882  Chevrolet    JohnAndretti
#  34883       Ford     MattKenseth
#
#  [34884 rows x 10 columns],
#  pandas.core.series.Series)

# %%
(df, pd.DataFrame)
# Out:
# (       serRace  year  yearRace  finish  start  laps  prize  carsRace  \
#  0            1  1975         1       1      1   191  12035        35
#  1            1  1975         1       2      2   191   8135        35
#  2            1  1975         1       3     25   184   6535        35
#  3            1  1975         1       4     27   183   5035        35
#  4            1  1975         1       5     22   178   3835        35
#  ...        ...   ...       ...     ...    ...   ...    ...       ...
#  34879      898  2003        36      39     17    89  43150        43
#  34880      898  2003        36      40     26    81  78703        43
#  34881      898  2003        36      41     23    72  60735        43
#  34882      898  2003        36      42     22    57  67612        43
#  34883      898  2003        36      43     37    28  62665        43
#
#           carMake          driver
#  0        Matador    BobbyAllison
#  1        Mercury    DavidPearson
#  2      Chevrolet     CecilGordon
#  3          Dodge      DaveMarcis
#  4           Ford     ElmoLangley
#  ...          ...             ...
#  34879  Chevrolet     MikeSkinner
#  34880      Dodge       JeffGreen
#  34881  Chevrolet  MichaelWaltrip
#  34882  Chevrolet    JohnAndretti
#  34883       Ford     MattKenseth
#
#  [34884 rows x 10 columns],
#  pandas.core.frame.DataFrame)

# %% [markdown]
# Task 12 - Dataset description and variable types
#
# Using your nascar DataFrame, answer the following questions. Remember - you can use methods like describe() and info() to print out information about the variable types in your DataFrame. Remember, you can use describe(exclude='number') to view non-numeric variable types.
#
# You can view more information about the data here.
#
# Select the letter indicating which one of the following statements about the features in nascar is incorrect? For example, if statement B is incorrect, you'll type your answer in the code block as answer = 'B'
#
# A: Each entry for driver is a text string
#
# B: carMake is an identifer variable
#
# C: carsRace is a quantitative, discrete variable
#
# D: prize is a quantitative, continuous variable

# %%
Answer='D'
print('D')
# Out:
# D
